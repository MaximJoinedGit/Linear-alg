# %% [markdown]
# ## <center>Линейная алгебра</center>
#
# <hr>

# %% [markdown]
# ### <center>Урок 1.</center>

# %% [markdown]
# ### 1. Исследовать на линейную зависимость:
# $f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}$

# %% [markdown]
# #### Проверим, является ли один из векторов в этой системе линейной комбинацией остальных.

# %% [markdown]
# $f_{4}(x) = f_{3}(x) - f_{1}(x) - f_{2}(x)$

# %% [markdown]
# $x - e^{x} = x + 1 - e^{x} - 1$

# %% [markdown]
# #### Да, четвертый вектор является линейной комбинацией остальных векторов, следовательно, система линейно зависима.

# %% [markdown]
# ### 2. Исследовать на линейную зависимость:
# $f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$

# %% [markdown]
# #### Также, как и в предыдущем задании, проверим, является ли один из векторов в этой системе линейной комбинацией остальных.

# %% [markdown]
# $f_{4}(x) = f_{3}(x) + 2 \cdot f_{2}(x) + 1/2 \cdot f_{1}(x)$

# %% [markdown]
# $x^2 + 2x + 1 = x^2 + 2x + 1$

# %% [markdown]
# #### В этом задании также четвертый вектор является линейной комбинацией остальных. Система линейно зависима.

# %% [markdown]
# ### 3. Найти координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$

# %% [markdown]
# $x = (2, 0, 0) + (0, 3, 0) + (0, 0, 5) = 1 \cdot (2, 0, 0) + 3 \cdot (0, 1, 0) + 1/2 \cdot (0, 0, 10) = 1b_{2} + 3b_{3} + 1/2b_{1}$

# %% [markdown]
# #### Координаты вектора х в новом базисе будут $x = (1/2, 1, 3)$

# %% [markdown]
# ### 4. Найти координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
# а) в базисе $1, x, x^{2}$;
#
# б) в базисе $x^{2}, x-1, 1$

# %% [markdown]
# #### a) Вектор $3x^2 - 2x + 2$ в базисе $1, x, x^2$ будет иметь координаты (2, -2, 3)

# %% [markdown]
# #### б) Вектор $3x^2 -2 \cdot (x - 1) + 0$ в базисе $x^2, x - 1, 1$ будет иметь координаты (3, -2, 0)

# %% [markdown]
# ### 5. Установить, является ли линейным подпространством:
#
# ### а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# ### б) все векторы, являющиеся линейными комбинациями данных векторов $(𝑢_1,𝑢_2,…,𝑢_𝑛)$

# %% [markdown]
# #### Оба варианта, исходя из определения линейного подпространства в линейном пространстве будут являться линейным подпространством

# %% [markdown]
# <hr>
#
# ### <center>Урок 2.</center>

# %% [markdown]
# ### 1. Найти скалярное произведение векторов $x, y \in \mathbb{R}$:<br>
# ### а) $x=(0,-3, 6),~y=(-4, 7, 9);$<br>
# ### б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2).$

# %% [markdown]
# #### a) $(x, y) = 0 \cdot (-4) + (-3) \cdot 7 + 6 \cdot 9 = 0 - 21 + 54 = 33$

# %% [markdown]
# #### б) $(x, y) = 7 \cdot (-3) + (-4) \cdot 1 + 0 \cdot 11 + 1 \cdot 2 = -21 - 4 + 0 + 2 = -23$

# %% [markdown]
# ### 2. Найти нормы векторов $(4, 2, 4)$ и $(12, 3, 4)$ и угол между ними.

# %% [markdown]
# #### Нормы векторов:

# %% [markdown]
# - Манхеттенская норма:
#
# |4| + |2| + |4| = 10
#
# |12| + |3| + |4| = 19

# %% [markdown]
# - Евклидова норма:
#
# $\sqrt{4^2 + 2^2 + 4^2} = \sqrt{36} = 6$
#
# $\sqrt{12^2 + 3^2 + 4^2} = \sqrt{169} = 13$

# %% [markdown]
# ### $cos\varphi = \frac{(x,y)}{\left \|x\right \|\cdot\left \|y\right \|} = \frac{4 \cdot 12 + 2 \cdot 3 + 4 \cdot 4}{6 \cdot 13} = 0.8974$

# %% [markdown]
# $\varphi = 26,18^{\circ}$

# %% [markdown]
# ### 3. Будет ли линейное пространство евклидовым, если за скалярное произведение принять:<br>
# #### а) произведение длин векторов;<br>
#
# Да, если произведение будет еще домножено на косинус угла между векторами.
# #### б) утроенное обычное скалярное произведение векторов?<br>
#
# Да

# %% [markdown]
# #### 4. Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$
# а) $(1,0,0),(0,0,1);$ <br>
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# г) $(1,0,0),(0,1,0),(0,0,1)?$

# %% [markdown]
# #### a) Не являются базисом потому что задано только два вектора в трехмерном пространстве
# #### б) Являются ортогональным базисом, но не нормированным
# #### в) Данные вектора не являются ни ортогональными, ни нормированными
# #### г) Являются ортонормированным базисом
